# %%
import matplotlib.pyplot as plt 
import numpy as np
import random
x = np.random.randint(10,60,(50))
print(x)
# Out:
# [43 36 40 11 25 43 42 18 33 56 46 57 29 45 16 47 51 48 34 44 46 44 23 34
#  46 51 19 13 34 16 41 40 49 12 46 43 32 22 51 58 30 47 40 14 30 18 46 38
#  16 40]

# %%
n = [48, 19, 29 ,37 ,41 ,20, 26, 47, 27, 48, 47, 52, 43, 58, 29, 19, 58, 30, 53, 24, 35, 26, 18, 54,
 35, 19, 29, 12, 45, 31, 31, 26, 23, 12, 13, 14, 31, 53, 19, 39, 28, 36, 47, 57, 32, 43, 32, 28,
 12, 52]

plt.hist(n,color="g",edgecolor="b")
plt.title("Demo Bar")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %% [markdown]
# ---

# %%
n = [48, 19, 29 ,37 ,41 ,20, 26, 47, 27, 48, 47, 52, 43, 58, 29, 19, 58, 30, 53, 24, 35, 26, 18, 54,
 35, 19, 29, 12, 45, 31, 31, 26, 23, 12, 13, 14, 31, 53, 19, 39, 28, 36, 47, 57, 32, 43, 32, 28,
 12, 52]
l=[10,20,30,40,50,60]
plt.hist(n,color="g",bins=l,edgecolor="b")
plt.title("Demo Bar")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %% [markdown]
# ---

# %%
n = [48, 19, 29 ,37 ,41 ,20, 26, 47, 27, 48, 47, 52, 43, 58, 29, 19, 58, 30, 53, 24, 35, 26, 18, 54,
 35, 19, 29, 12, 45, 31, 31, 26, 23, 12, 13, 14, 31, 53, 19, 39, 28, 36, 47, 57, 32, 43, 32, 28,
 12, 52]

plt.hist(n,"auto",(0,100),edgecolor="b")
plt.title("Demo Bar")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
n = [48, 19, 29 ,37 ,41 ,20, 26, 47, 27, 48, 47, 52, 43, 58, 29, 19, 58, 30, 53, 24, 35, 26, 18, 54,
 35, 19, 29, 12, 45, 31, 31, 26, 23, 12, 13, 14, 31, 53, 19, 39, 28, 36, 47, 57, 32, 43, 32, 28,
 12, 52]
l=[10,20,30,40,50,60]
plt.hist(n,color="g",edgecolor="b",cumulative=-1)
plt.title("Demo Bar")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %% [markdown]
# ---

# %%
n = [48, 19, 29 ,37 ,41 ,20, 26, 47, 27, 48, 47, 52, 43, 58, 29, 19, 58, 30, 53, 24, 35, 26, 18, 54,
 35, 19, 29, 12, 45, 31, 31, 26, 23, 12, 13, 14, 31, 53, 19, 39, 28, 36, 47, 57, 32, 43, 32, 28,
 12, 52]
l=[10,20,30,40,50,60]
plt.hist(n,color="g",edgecolor="b",cumulative=-1,bottom=10)
plt.title("Demo Bar")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
n = [48, 19, 29 ,37 ,41 ,20, 26, 47, 27, 48, 47, 52, 43, 58, 29, 19, 58, 30, 53, 24, 35, 26, 18, 54,
 35, 19, 29, 12, 45, 31, 31, 26, 23, 12, 13, 14, 31, 53, 19, 39, 28, 36, 47, 57, 32, 43, 32, 28,
 12, 52]
l=[10,20,30,40,50,60]
plt.hist(n,color="g",edgecolor="b")
plt.title("Demo Bar")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
n = [48, 19, 29 ,37 ,41 ,20, 26, 47, 27, 48, 47, 52, 43, 58, 29, 19, 58, 30, 53, 24, 35, 26, 18, 54,
 35, 19, 29, 12, 45, 31, 31, 26, 23, 12, 13, 14, 31, 53, 19, 39, 28, 36, 47, 57, 32, 43, 32, 28,
 12, 52]
l=[10,20,30,40,50,60]
plt.hist(n,color="g",edgecolor="b",align="mid")
plt.title("Demo Bar")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %% [markdown]
# ---

# %%
n = [48, 19, 29 ,37 ,41 ,20, 26, 47, 27, 48, 47, 52, 43, 58, 29, 19, 58, 30, 53, 24, 35, 26, 18, 54,
 35, 19, 29, 12, 45, 31, 31, 26, 23, 12, 13, 14, 31, 53, 19, 39, 28, 36, 47, 57, 32, 43, 32, 28,
 12, 52]
l=[10,20,30,40,50,60]
plt.hist(n,color="g",edgecolor="b",align="mid",histtype="step")
plt.title("Demo Bar")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %% [markdown]
# ---

# %%
n = [48, 19, 29 ,37 ,41 ,20, 26, 47, 27, 48, 47, 52, 43, 58, 29, 19, 58, 30, 53, 24, 35, 26, 18, 54,
 35, 19, 29, 12, 45, 31, 31, 26, 23, 12, 13, 14, 31, 53, 19, 39, 28, 36, 47, 57, 32, 43, 32, 28,
 12, 52]
l=[10,20,30,40,50,60]
plt.hist(n,color="g",edgecolor="b",align="mid",histtype="bar",label="python",orientation = "horizontal",rwidth=0.75,log=2
         )
plt.title("Demo Bar")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %% [markdown]
# ---

# %%
n = [48, 19, 29 ,37 ,41 ,20, 26, 47, 27, 48, 47, 52, 43, 58, 29, 19, 58, 30, 53, 24, 35, 26, 18, 54,
 35, 19, 29, 12, 45, 31, 31, 26, 23, 12, 13, 14, 31, 53, 19, 39, 28, 36, 47, 57, 32, 43, 32, 28,
 12, 52]
l=[10,20,30,40,50,60]
plt.hist(n,color="g",edgecolor="b",align="mid",histtype="bar",label="python",rwidth=0.75
         )
plt.title("Demo Bar")
plt.xlabel("Python")
plt.ylabel("No.")
plt.axvline(45,color="y")
plt.show()
