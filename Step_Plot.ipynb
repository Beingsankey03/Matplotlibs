# %% [markdown]
# # **STEP PLOT**

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [1,2,4,5,6]

plt.step(x,y,color="r",marker="o",mfc="g",label="python")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Box Plot")
plt.legend(loc=2)
plt.show()
